# %%
# !pip install requests gradio -q
# Out:
# 3496.85s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# [notice] A new release of pip is available: 23.1.1 -> 23.1.2
# [notice] To update, run: python -m pip install --upgrade pip

# %%
# !pip install cohere -q
# Out:
# 3505.25s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# [notice] A new release of pip is available: 23.1.1 -> 23.1.2
# [notice] To update, run: python -m pip install --upgrade pip

# %%
import cohere
co = cohere.Client('')

# %%
def write_topic(topic):
  topic = str(topic)
  response = co.generate(
    model='command-xlarge-nightly',
    prompt= f'Create a SEO blogpost with Table of Contents for the \"{topic}"\:',
    max_tokens=2130,
    temperature=0.9,
    k=0,
    stop_sequences=[],
    return_likelihoods='NONE')
  return print('Prediction: {}'.format(response.generations[0].text))

# %%
write_topic('animal')
# Out:
# Prediction:
#
# Table of Contents
# - What is an Animal?
# - Different Types of Animals
# - Structure of Animals
# - Function of Animals
# - Evolution of Animals
# - Distribution of Animals
# - Adaptation in Animals
# - Conclusion
#
# What is an Animal?
# An animal is a multicellular and heterotroph eukaryotic organism. All animals have a nervous system. An animal can move from one place to another. They can feed themselves and have a life of their own.
# The definition of an animal is not very clear. It is hard to draw a line between animals and other eukaryotic organisms. For example, sponges were once considered animals, but now they are not.
# There are about 30,000 species of animals.
#
# Different Types of Animals
# There are two main types of animals: vertebrates and invertebrates.
#
# Vertebrates:
# These animals have a backbone. They are the most intelligent and strongest of all animals. Vertebrates make up only 5% of the animals on Earth. The Vertebrates are divided into four types: mammals, birds, reptiles, and amphibians.
#
# Mammals:
# These are the most intelligent animals. They have the largest brain of all animals. They give birth to a baby, which is called a mammal.
#
# Birds:
# These animals have wings and feathers. They are the fastest-flying animals.
#
# Reptiles:
# These animals have dry skin. They include snakes, lizards, and crocodiles.
#
# Amphibians:
# These animals can live both on land and in water. They are cold-blooded animals.
#
# Invertebrates:
# These animals do not have a backbone. They are the most numerous of all animals. Invertebrates make up about 95% of the animals on Earth. They are divided into four types: sponges, jellyfish, worms, and shellfish.
#
# Worms:
# These animals have long, thin bodies. They do not have a backbone.
#
# Jellyfish:
# These animals are the most primitive of all animals. They do not have a backbone. The jellyfish is a type of invertebrate that has existed for over 500 million years.
#
# Sponges:
# These animals are the first multicellular animal. They do not have a backbone. The sponge is the only animal that can live on a non-living thing.
#
# Conclusion:
# All animals are important for the environment. They maintain the balance in the ecosystem. The animals are divided into two main types: vertebrates and invertebrates.

# %%
pip install streamlit
# Out:
# 3578.19s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Requirement already satisfied: streamlit in /usr/local/python/3.10.4/lib/python3.10/site-packages (1.22.0)
# Requirement already satisfied: altair<5,>=3.2.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from streamlit) (4.2.2)
# Requirement already satisfied: blinker>=1.0.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from streamlit) (5.3.0)
# Requirement already satisfied: click>=7.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from streamlit) (8.1.3)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from streamlit) (6.6.0)
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.10/site-packages (from streamlit) (1.24.3)
# Requirement already satisfied: packaging>=14.1 in /home/codespace/.local/lib/python3.10/site-packages (from streamlit) (23.1)
# Requirement already satisfied: pandas<3,>=0.25 in /home/codespace/.local/lib/python3.10/site-packages (from streamlit) (2.0.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from streamlit) (9.5.0)
# Requirement already satisfied: protobuf<4,>=3.12 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=4.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from streamlit) (12.0.0)
# Requirement already satisfied: pympler>=0.9 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from streamlit) (1.0.1)
# Requirement already satisfied: python-dateutil in /home/codespace/.local/lib/python3.10/site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests>=2.4 in /home/codespace/.local/lib/python3.10/site-packages (from streamlit) (2.28.2)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from streamlit) (13.3.5)
# Requirement already satisfied: tenacity<9,>=8.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml in /usr/local/python/3.10.4/lib/python3.10/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from streamlit) (4.5.0)
# Requirement already satisfied: tzlocal>=1.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from streamlit) (4.3)
# Requirement already satisfied: validators>=0.2 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from streamlit) (0.20.0)
# Requirement already satisfied: gitpython!=3.1.19 in /home/codespace/.local/lib/python3.10/site-packages (from streamlit) (3.1.31)
# Requirement already satisfied: pydeck>=0.1.dev5 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from streamlit) (0.8.1b0)
# Requirement already satisfied: tornado>=6.0.3 in /home/codespace/.local/lib/python3.10/site-packages (from streamlit) (6.3.1)
# Requirement already satisfied: watchdog in /usr/local/python/3.10.4/lib/python3.10/site-packages (from streamlit) (3.0.0)
# Requirement already satisfied: entrypoints in /usr/local/python/3.10.4/lib/python3.10/site-packages (from altair<5,>=3.2.0->streamlit) (0.4)
# Requirement already satisfied: jinja2 in /home/codespace/.local/lib/python3.10/site-packages (from altair<5,>=3.2.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /home/codespace/.local/lib/python3.10/site-packages (from altair<5,>=3.2.0->streamlit) (4.17.3)
# Requirement already satisfied: toolz in /usr/local/python/3.10.4/lib/python3.10/site-packages (from altair<5,>=3.2.0->streamlit) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from gitpython!=3.1.19->streamlit) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from importlib-metadata>=1.4->streamlit) (3.15.0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas<3,>=0.25->streamlit) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas<3,>=0.25->streamlit) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.4->streamlit) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.4->streamlit) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.4->streamlit) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.4->streamlit) (2022.12.7)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from rich>=10.11.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/codespace/.local/lib/python3.10/site-packages (from rich>=10.11.0->streamlit) (2.15.1)
# Requirement already satisfied: pytz-deprecation-shim in /usr/local/python/3.10.4/lib/python3.10/site-packages (from tzlocal>=1.1->streamlit) (0.1.0.post0)
# Requirement already satisfied: decorator>=3.4.0 in /home/codespace/.local/lib/python3.10/site-packages (from validators>=0.2->streamlit) (5.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit) (5.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.10/site-packages (from jinja2->altair<5,>=3.2.0->streamlit) (2.1.2)
# Requirement already satisfied: attrs>=17.4.0 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit) (0.19.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->streamlit) (0.1.2)
#
# [notice] A new release of pip is available: 23.1.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import cohere
co = cohere.Client('gh7zeWIg1ZDBOGjYP09jnBDpUoHpo7Q4GEZwQ2zq')
def write_topic(topic):
  topic = str(topic)
  response = co.generate(
    model='command-xlarge-nightly',
    prompt= f'Create a SEO blogpost with Table of Contents for the \"{topic}"\:',
    max_tokens=2130,
    temperature=0.9,
    k=0,
    stop_sequences=[],
    return_likelihoods='NONE')
  print('Prediction: {}'.format(response.generations[0].text))

# %%
import gradio as gr

# %%
with gr.Blocks() as demo:
  gr.Markdown("# AI generated Blogpost with Cohere API")
  #with gr.Row():
  inp = gr.Textbox(placeholder="Enter your Topic for Blog post Generation", label = "Topic")
  btn = gr.Button("Generate ")
  out = gr.Textbox()
  btn.click(fn=write_topic, inputs=inp, outputs=out)

demo.launch(debug=False)
# Out:
# <function write_topic at 0x7f99cf893d90>
# Running on local URL:  http://127.0.0.1:7864
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:
# - [O elephant](o-elephant.md)
# - [Giant panda](giant-panda.md)
# - [O elephant](o-elephant.md)
# - [Giant panda](giant-panda.md)
# - [ Honey badger](honey-badger.md)
# - [Ostrich](ostrich.md)
# - [Emu](emu.md)
# - [Moose](moose.md)
# - [Elk](elk.md)
# - [Deer](deer.md)
# - [Reindeer](reindeer.md)
# - [ Caribou](caribou.md)
# - [Leopard](leopard.md)
# - [Jaguar](jaguar.md)
# - [Puma](puma.md)
# - [Cheetah](cheetah.md)
# - [Giraffe](giraffe.md)
# - [S zebra](s-zebra.md)
# - [Hippopotamus](hippopotamus.md)
# - [ Rhino](rhino.md
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "/home/codespace/.python/current/lib/python3.10/site-packages/uvicorn/protocols/http/h11_impl.py", line 428, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "/home/codespace/.python/current/lib/python3.10/site-packages/uvicorn/middleware/proxy_headers.py", line 78, in __call__
#     return await self.app(scope, receive, send)
#   File "/home/codespace/.python/current/lib/python3.10/site-packages/fastapi/applications.py", line 276, in __call__
#     await super().__call__(scope, receive, send)
#   File "/home/codespace/.python/current/lib/python3.10/site-packages/starlette/applications.py", line 122, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/home/codespace/.python/current/lib/python3.10/site-packages/starlette/middleware/errors.py", line 184, in __call__
#     raise exc
#   File "/home/codespace/.python/current/lib/python3.10/site-packages/starlette/middleware/errors.py", line 162, in __call__
#     await self.app(scope, receive, _send)
#   File "/home/codespace/.python/current/lib/python3.10/site-packages/starlette/middleware/cors.py", line 84, in __call__
#     await self.app(scope, receive, send)
#   File "/home/codespace/.python/current/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 79, in __call__
#     raise exc
#   File "/home/codespace/.python/current/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 68, in __call__
#     await self.app(scope, receive, sender)
#   File "/home/codespace/.python/current/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 21, in __call__
#     raise e
#   File "/home/codespace/.python/current/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "/home/codespace/.python/current/lib/python3.10/site-packages/starlette/routing.py", line 718, in __call__
#     await route.handle(scope, receive, send)
#   File "/home/codespace/.python/current/lib/python3.10/site-packages/starlette/routing.py", line 276, in handle
#     await self.app(scope, receive, send)
#   File "/home/codespace/.python/current/lib/python3.10/site-packages/starlette/routing.py", line 66, in app
#     response = await func(request)
#   File "/home/codespace/.python/current/lib/python3.10/site-packages/fastapi/routing.py", line 237, in app
#     raw_response = await run_endpoint_function(
#   File "/home/codespace/.python/current/lib/python3.10/site-packages/fastapi/routing.py", line 165, in run_endpoint_function
#     return await run_in_threadpool(dependant.call, **values)
#   File "/home/codespace/.python/current/lib/python3.10/site-packages/starlette/concurrency.py", line 41, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func, *args)
#   File "/home/codespace/.local/lib/python3.10/site-packages/anyio/to_thread.py", line 31, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(
#   File "/home/codespace/.local/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 937, in run_sync_in_worker_thread
#     return await future
#   File "/home/codespace/.local/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 867, in run
#     result = context.run(func, *args)
#   File "/home/codespace/.python/current/lib/python3.10/site-packages/gradio/routes.py", line 260, in api_info
#     return gradio.blocks.get_api_info(config, serialize)  # type: ignore
#   File "/home/codespace/.python/current/lib/python3.10/site-packages/gradio/blocks.py", line 499, in get_api_info
#     info = component["api_info"]["serialized_input"]
# KeyError: 'serialized_input'
# Prediction:
#
# Table of Contents
#
# - What is Animal locomotion?
# - What are the different types of Animal locomotion?
# - How does Animal locomotion work?
# - What are the different types of Animal locomotion?
# - What is the difference between Animal locomotion and Plant locomotion?
# - How many different types of Animal locomotion are there?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What are the different types of Animal locomotion?
# - What
